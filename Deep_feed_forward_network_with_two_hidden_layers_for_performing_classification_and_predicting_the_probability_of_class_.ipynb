# %% [markdown]
# <a href="https://colab.research.google.com/github/mscitpract/DL/blob/main/Deep_feed_forward_network_with_two_hidden_layers_for_performing_classification_and_predicting_the_probability_of_class_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_wine
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from keras.layers import Dense, Input, concatenate, Dropout
from keras.models import Model
from tensorflow.keras import optimizers
optimizers.RMSprop
optimizers.Adam
dataset = load_wine()
ensemble_num = 10
bootstrap_size = 0.8
training_size = 0.8
num_hidden_neurosn = 10
dropout = 0.25
epochs = 100
batch = 10
temp = []
scaler = MinMaxScaler()
one_hot = OneHotEncoder()
dataset['data'] = scaler.fit_transform(dataset['data'])
dataset['target'] = one_hot.fit_transform(np.reshape(dataset['target'], (-1, 1))).toarray()
for i in range(len(dataset.data)):
  temp.append([dataset['data'][i], np.array(dataset['target'][i])])
temp = np.array(temp, dtype=object)
np.random.shuffle(temp)
#holdout training and test stop index
stop = int(training_size*len(dataset.data))
train_X = np.array([x for x in temp[:stop, 0]])
train_Y = np.array([x for x in temp[:stop, 1]])
test_X = np.array([x for x in temp[stop:, 0]])
test_Y = np.array([x for x in temp[stop:, 1]])
num_hidden_neurons = 64
sub_net_outputs = []
sub_net_inputs = []
for i in range(ensemble_num):
#two hidden layers to keep it simple
# specify input shape to the shape of the training set
  net_input = Input(shape=(train_X.shape[1],))
  sub_net_inputs.append(net_input)
  Y = Dense(num_hidden_neurons)(net_input)
  Y = Dense(num_hidden_neurons)(Y)
  Y = Dropout(dropout)(Y)
# sub_nets contains the output tensors
  sub_net_outputs.append(Y)
Y = concatenate(sub_net_outputs)
Y = Dense(train_Y[0].shape[0], activation='softmax')(Y)
model = Model(inputs=sub_net_inputs, outputs=Y)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
print('\n')
print("7_Aditya Hadap")
print("Begin training...")
model.fit([train_X] * ensemble_num, train_Y, validation_data=[[test_X] * ensemble_num,
test_Y], epochs=epochs, batch_size=batch)
print("Training complete...")
np.set_printoptions(precision=2, suppress=True)
for i in range(len(test_X)):
  print("Prediction: " + str(model.predict([test_X[i].reshape(1, test_X[i].shape[0])] *
ensemble_num)) + " | True: " + str(test_Y[i]))
# Out:
# 7_Aditya Hadap
# Begin training...
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.0599 - val_loss: 0.5241
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4992 - val_loss: 0.2388
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2806 - val_loss: 0.2027
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2293 - val_loss: 0.3236
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1855 - val_loss: 0.3135
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1885 - val_loss: 0.0921
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1151 - val_loss: 0.1576
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0808 - val_loss: 0.0562
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0882 - val_loss: 0.1748
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0608 - val_loss: 0.1454
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0601 - val_loss: 0.1195
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0464 - val_loss: 0.1755
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0592 - val_loss: 0.1748
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0472 - val_loss: 0.2457
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0344 - val_loss: 0.2737
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0415 - val_loss: 0.2242
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0222 - val_loss: 0.1864
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0239 - val_loss: 0.0646
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0192 - val_loss: 0.0866
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0221 - val_loss: 0.3113
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0361 - val_loss: 0.0364
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0171 - val_loss: 0.1001
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153 - val_loss: 0.1444
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0156 - val_loss: 0.2037
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0111 - val_loss: 0.1091
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0092 - val_loss: 0.2985
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0192 - val_loss: 0.1660
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0125 - val_loss: 0.1004
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0056 - val_loss: 0.1862
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0104 - val_loss: 0.2007
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045 - val_loss: 0.1236
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - val_loss: 0.3074
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0109 - val_loss: 0.2591
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0072 - val_loss: 0.2798
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - val_loss: 0.3010
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - val_loss: 0.1662
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - val_loss: 0.2891
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - val_loss: 0.1630
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 0.2455
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079 - val_loss: 0.1946
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.1095
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - val_loss: 0.2640
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.1988
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.3106
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.3029
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1273e-04 - val_loss: 0.1203
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.3735
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - val_loss: 0.3034
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.2334
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 0.2884
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - val_loss: 0.1923
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.1694
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8864e-04 - val_loss: 0.2350
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - val_loss: 0.1845
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0456e-04 - val_loss: 0.1530
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7955e-04 - val_loss: 0.1377
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - val_loss: 0.1765
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6368e-04 - val_loss: 0.1806
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4319e-04 - val_loss: 0.2200
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1341e-04 - val_loss: 0.2431
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8919e-04 - val_loss: 0.0167
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - val_loss: 0.2018
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4214e-04 - val_loss: 0.2067
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4330e-04 - val_loss: 0.1751
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - val_loss: 0.1623
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0068e-04 - val_loss: 0.1797
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3870e-04 - val_loss: 0.1683
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 0.4115
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 0.3509
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5861e-04 - val_loss: 0.2213
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5321e-04 - val_loss: 0.1777
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2743e-04 - val_loss: 0.3731
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8642e-04 - val_loss: 0.4833
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 0.1531
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5804e-04 - val_loss: 0.2593
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0975e-04 - val_loss: 0.2578
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6937e-04 - val_loss: 0.2333
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9441e-04 - val_loss: 0.2452
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0122e-04 - val_loss: 0.3313
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8712e-04 - val_loss: 0.2349
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3870e-04 - val_loss: 0.2016
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4750e-04 - val_loss: 0.2590
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7032e-04 - val_loss: 0.2265
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2095e-04 - val_loss: 0.2205
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7395e-04 - val_loss: 0.1151
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4833e-04 - val_loss: 0.2963
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6089e-04 - val_loss: 0.2269
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0874e-04 - val_loss: 0.2323
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8104e-04 - val_loss: 0.2325
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2732e-04 - val_loss: 0.2592
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8300e-04 - val_loss: 0.2221
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4915e-04 - val_loss: 0.1987
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8618e-05 - val_loss: 0.2253
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1673e-04 - val_loss: 0.1996
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1673e-04 - val_loss: 0.1963
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1740e-04 - val_loss: 0.1873
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9758e-05 - val_loss: 0.2562
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1681e-04 - val_loss: 0.1593
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5034e-04 - val_loss: 0.2248
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1495e-04 - val_loss: 0.2089
# Training complete...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: [[0.58 0.42 0.  ]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Prediction: [[0. 1. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Prediction: [[1. 0. 0.]] | True: [1. 0. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: [[0. 1. 0.]] | True: [0. 1. 0.]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Prediction: [[0. 0. 1.]] | True: [0. 0. 1.]
